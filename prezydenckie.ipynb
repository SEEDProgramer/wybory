# %%
import pandas as pd
import numpy as np

# %%
data = pd.ExcelFile('wyniki_gl_na_kand_po_obwodach_utf8.xlsx')

# %%
data.sheet_names
# Out:
# ['wyniki_gl_na_kand_po_obwodach']

# %%
df = pd.read_excel('wyniki_gl_na_kand_po_obwodach_utf8.xlsx')
df.shape
# Out:
# (27229, 44)

# %%
dir(df)

# %%
df.replace('-', np.nan, inplace = True)

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
#                               Symbol kontrolny  Nr OKW  Kod TERYT  \
# 27220  be7e-206d-8c4f-0909-0acd-bf00-54b6-ff2b    48.0   326301.0
# 27221  2148-b29b-595c-cbcf-a56e-bbf0-0856-25e4    48.0   326301.0
# 27222  ba7b-74fa-08b3-5b4c-c5f1-f5eb-587b-2de5    48.0   326301.0
# 27223  f489-a349-705a-526d-3fe8-8a95-220f-4196    48.0   326301.0
# 27224  d6a0-0c31-15b5-3d00-d1ae-e279-0a91-2e68    48.0   326301.0
#
#            Typ gminy  Numer obwodu Typ obszaru        Typ obwodu  \
# 27220  gmina miejska            23      miasto             stały
# 27221  gmina miejska            24      miasto             stały
# 27222  gmina miejska            25      miasto             stały
# 27223  gmina miejska            26      miasto  zakład leczniczy
# 27224  gmina miejska            27      miasto  zakład leczniczy
#
#                                                 Siedziba           Gmina  \
# 27220  Miejski Dom Kultury Filia Nr 2, Świnoujście, W...  m. Świnoujście
# ...

# %%
df.dtypes
# Out:
# Symbol kontrolny                                                                                  object
# Nr OKW                                                                                           float64
# Kod TERYT                                                                                        float64
# Typ gminy                                                                                         object
# Numer obwodu                                                                                       int64
# Typ obszaru                                                                                       object
# Typ obwodu                                                                                        object
# Siedziba                                                                                          object
# Gmina                                                                                             object
# ...

# %%
df.describe()
# Out:
#              Nr OKW      Kod TERYT  Numer obwodu  \
# count  27225.000000   27225.000000  27225.000000
# mean      25.454876  166320.197098     38.244298
# std       13.814901   89815.117737    111.457843
# min        1.000000   20101.000000      1.000000
# 25%       14.000000  101002.000000      3.000000
# 50%       26.000000  146513.000000      7.000000
# 75%       37.000000  241711.000000     18.000000
# max       49.000000  326301.000000   1147.000000
#
#        Komisje obwodowe otrzymały kart do głosowania  \
# count                                   27225.000000
# mean                                      988.241212
# std                                       527.817287
# min                                         0.000000
# 25%                                       580.000000
# 50%                                       950.000000
# 75%                                      1364.000000
# max                                      4474.000000
#
# ...

# %%
df.keys()
# Out:
# Index(['Symbol kontrolny', 'Nr OKW', 'Kod TERYT', 'Typ gminy', 'Numer obwodu',
#        'Typ obszaru', 'Typ obwodu', 'Siedziba', 'Gmina', 'Powiat',
#        'Województwo', 'Komisje obwodowe otrzymały kart do głosowania',
#        'Liczba wyborców uprawnionych do głosowania',
#        'Nie wykorzystano kart do głosowania',
#        'Liczba wyborców, którym wydano karty do głosowania',
#        'Liczba wyborców głosujących przez pełnomocnika',
#        'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#        'Liczba wyborców, którym wysłano pakiety wyborcze',
#        'Liczba otrzymanych kopert zwrotnych',
#        'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#        'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane',
#        'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
# ...

# %%
debile = df.keys().tolist()[33:]
df_small = df[debile]
df_small.describe()
# Out:
#         Robert BIEDROŃ  Krzysztof BOSAK  Andrzej Sebastian DUDA  \
# count            27229            27229                   27229
# unique             152              248                     963
# top                  3                0                     226
# freq              1399              771                      97
#
#         Szymon Franciszek HOŁOWNIA  Marek JAKUBIAK  \
# count                        27229           27229
# unique                         482              26
# top                              0               0
# freq                           408           11135
#
#         Władysław Marcin KOSINIAK-KAMYSZ  Mirosław Mariusz PIOTROWSKI  \
# count                              27229                        27229
# unique                               114                           15
# top                                   10                            0
# freq                                1125                        15010
#
# ...

# %%
df_gmina = df.groupby(['Gmina']).sum()
df_polska = df[df['Gmina']!='zagranica']
df_polska = df_polska[debile]
df_polska.describe()
# Out:
#        Robert BIEDROŃ  Krzysztof BOSAK  Andrzej Sebastian DUDA  \
# count    27060.000000     27060.000000            27060.000000
# mean        15.440244        47.674205              309.889468
# std         14.604095        31.812249              165.577512
# min          0.000000         0.000000                0.000000
# 25%          5.000000        24.000000              195.000000
# 50%         11.000000        43.000000              296.000000
# 75%         22.000000        67.000000              407.000000
# max        132.000000       316.000000             1407.000000
#
#        Szymon Franciszek HOŁOWNIA  Marek JAKUBIAK  \
# count                27060.000000    27060.000000
# mean                    97.731781        1.221508
# std                     73.451704        1.480278
# min                      0.000000        0.000000
# 25%                     39.000000        0.000000
# 50%                     85.000000        1.000000
# ...

# %%
df_gmina.nlargest(3,'Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów')
# Out:
#             Nr OKW   Kod TERYT  Numer obwodu  \
# Gmina
# m. Kraków   8046.0  56367147.0        100128
# m. Wrocław   312.0   8237112.0         48828
# m. Łódź     4396.0  33315714.0         49455
#
#             Komisje obwodowe otrzymały kart do głosowania  \
# Gmina
# m. Kraków                                        550911.0
# m. Wrocław                                       445115.0
# m. Łódź                                          481497.0
#
#             Liczba wyborców uprawnionych do głosowania  \
# Gmina
# m. Kraków                                     606178.0
# m. Wrocław                                    503769.0
# m. Łódź                                       522350.0
#
#             Nie wykorzystano kart do głosowania  \
# Gmina
# m. Kraków                              122506.0
# m. Wrocław                              92100.0
# m. Łódź                                132572.0
#
#             Liczba wyborców, którym wydano karty do głosowania  \
# Gmina
# ...

# %%
df_deb=df_gmina.nlargest(3,'Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów')
for a in debile:
    print(df_gmina.nlargest(3,a))
# Out:
#             Nr OKW   Kod TERYT  Numer obwodu  \
# Gmina
# m. Kraków   8046.0  56367147.0        100128
# zagranica   3465.0  24733665.0         14102
# m. Wrocław   312.0   8237112.0         48828
#
#             Komisje obwodowe otrzymały kart do głosowania  \
# Gmina
# m. Kraków                                        550911.0
# zagranica                                         41489.0
# m. Wrocław                                       445115.0
#
#             Liczba wyborców uprawnionych do głosowania  \
# Gmina
# m. Kraków                                     606178.0
# zagranica                                     373929.0
# m. Wrocław                                    503769.0
#
#             Nie wykorzystano kart do głosowania  \
# Gmina
# m. Kraków                              122506.0
# zagranica                               12530.0
# m. Wrocław                              92100.0
#
#             Liczba wyborców, którym wydano karty do głosowania  \
# Gmina
# ...

# %%
df_deb
# Out:
#             Nr OKW   Kod TERYT  Numer obwodu  \
# Gmina
# m. Kraków   8046.0  56367147.0        100128
# m. Wrocław   312.0   8237112.0         48828
# m. Łódź     4396.0  33315714.0         49455
#
#             Komisje obwodowe otrzymały kart do głosowania  \
# Gmina
# m. Kraków                                        550911.0
# m. Wrocław                                       445115.0
# m. Łódź                                          481497.0
#
#             Liczba wyborców uprawnionych do głosowania  \
# Gmina
# m. Kraków                                     606178.0
# m. Wrocław                                    503769.0
# m. Łódź                                       522350.0
#
#             Nie wykorzystano kart do głosowania  \
# Gmina
# m. Kraków                              122506.0
# m. Wrocław                              92100.0
# m. Łódź                                132572.0
#
#             Liczba wyborców, którym wydano karty do głosowania  \
# Gmina
# ...

# %%
dz = df[df['Gmina']=='zagranica']

# %%
dz[['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile].sum()
# Out:
# Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów    310699.0
# Robert BIEDROŃ                                                      14313.0
# Krzysztof BOSAK                                                     27219.0
# Andrzej Sebastian DUDA                                              64732.0
# Szymon Franciszek HOŁOWNIA                                          48721.0
# Marek JAKUBIAK                                                        595.0
# Władysław Marcin KOSINIAK-KAMYSZ                                     3264.0
# Mirosław Mariusz PIOTROWSKI                                           224.0
# Paweł Jan TANAJNO                                                     564.0
# Rafał Kazimierz TRZASKOWSKI                                        149651.0
# Waldemar Włodzimierz WITKOWSKI                                        942.0
# Stanisław Józef ŻÓŁTEK                                                474.0
# dtype: float64

# %%
for debil in debile:
    dz[debil] = dz[debil]*100/dz['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów']
# Out:
# <ipython-input-17-54fa655bd0d1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dz[debil] = dz[debil]*100/dz['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów']

# %%
dz = dz.sort_values(by='Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów', ascending=False)
dz[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13991  Manchester I, Konsulat Generalny RP, 51 Portla...
# 13992  Manchester II, Konsulat Generalny RP, 51 Portl...
# 13986  Londyn I, Ambasada RP w Londynie 47 Portland P...
# 14004  Poland House 90 Gloucester Place London W1U 6H...
# 13987  Londyn II, Ambasada RP w Londynie 47 Portland ...
# ...                                                  ...
# 13896  Islamska Republika Iranu, Teheran, Ambasada RP...
# 13880  Addis Abeba, Ambasada RP Dej. Belay Zeleke Roa...
# 13943  Islamabad, Ambasada RP Diplomatic Enclave II, ...
# 13893  Mumbaj, Konsulat Generalny RP Nirmal Building,...
# 14005  Smoleńsk, Agencja Konsularna RP Mira 1 214014 ...
#
#        Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# 13991                                            13341.0
# 13992                                            12990.0
# 13986                                            11310.0
# ...

# %%
dz[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13991  Manchester I, Konsulat Generalny RP, 51 Portla...
# 13992  Manchester II, Konsulat Generalny RP, 51 Portl...
# 13986  Londyn I, Ambasada RP w Londynie 47 Portland P...
# 14004  Poland House 90 Gloucester Place London W1U 6H...
# 13987  Londyn II, Ambasada RP w Londynie 47 Portland ...
# ...                                                  ...
# 13896  Islamska Republika Iranu, Teheran, Ambasada RP...
# 13880  Addis Abeba, Ambasada RP Dej. Belay Zeleke Roa...
# 13943  Islamabad, Ambasada RP Diplomatic Enclave II, ...
# 13893  Mumbaj, Konsulat Generalny RP Nirmal Building,...
# 14005  Smoleńsk, Agencja Konsularna RP Mira 1 214014 ...
#
#        Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# 13991                                            13341.0
# 13992                                            12990.0
# 13986                                            11310.0
# ...

# %%
dd = dz.nlargest(5,'Andrzej Sebastian DUDA')
dd[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13949  Irkuck, Konsulat Generalny RP Suche-Batora 18 ...
# 13982  Winnica, Konsulat Generalny RP Mykoly Ovodova ...
# 13967  Chicago II, Konsulat Generalny RP 1530 N Lake ...
# 13966  Chicago I, Konsulat Generalny RP 1530 N Lake S...
# 13968  Chicago III, Konsulat Generalny RP 1530 N Lake...
#
#        Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# 13949                                               35.0
# 13982                                               86.0
# 13967                                             3308.0
# 13966                                             3363.0
# 13968                                             3331.0
#
#        Robert BIEDROŃ  Krzysztof BOSAK  Andrzej Sebastian DUDA  \
# 13949        0.000000         2.857143               91.428571
# 13982        0.000000         5.813953               89.534884
# 13967        0.937122         4.836759               68.893591
# ...

# %%
dd = dz.nlargest(5,'Rafał Kazimierz TRZASKOWSKI')
dd[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13955  Singapur, Ambasada RP 435 Orchard Road #17 - 0...
# 13892  Nowe Delhi, Ambasada RP 50 - M Shantipath, Cha...
# 13923  Malezja, Kuala Lumpur, Ambasada RP No. 10 Loro...
# 13844  Tirana, Ambasada RP Rruga e Durresit 123 Tiran...
# 13926  Meksyk, Ambasada RP calle Cracovia 40, colonia...
#
#        Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# 13955                                              421.0
# 13892                                               48.0
# 13923                                              108.0
# 13844                                               30.0
# 13926                                              214.0
#
#        Robert BIEDROŃ  Krzysztof BOSAK  Andrzej Sebastian DUDA  \
# 13955        4.988124         6.650831                3.325416
# 13892        2.083333         4.166667               14.583333
# 13923        9.259259         3.703704                4.629630
# ...

# %%
dd = dz.nlargest(15,'Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów')
dd[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13991  Manchester I, Konsulat Generalny RP, 51 Portla...
# 13992  Manchester II, Konsulat Generalny RP, 51 Portl...
# 13986  Londyn I, Ambasada RP w Londynie 47 Portland P...
# 14004  Poland House 90 Gloucester Place London W1U 6H...
# 13987  Londyn II, Ambasada RP w Londynie 47 Portland ...
# 13988  Londyn III, Ambasada RP w Londynie 47 Portland...
# 13990  Londyn V, Wydział Konsularny Ambasady RP w Lon...
# 13989  Londyn IV, Wydział Konsularny Ambasady RP w Lo...
# 13928  Haga I, Ambasada RP Alexanderstraat 25 2514 JM...
# 13929  Haga II, Ambasada RP (dawny WPHI) Van Lennepwe...
# 13898  Republika Irlandii, Dublin, Rezydencja Ambasad...
# 13899  Republika Irlandii, Dublin, Wydział Konsularny...
# 13897  Republika Irlandii, Dublin, Ambasada RP 5 Aile...
# 13993  Edynburg I, Konsulat Generalny RP 2 Kinnear Ro...
# 13994  Edynburg II, Konsulat Generalny RP 2 Kinnear R...
#
# ...

# %%
dz_large = dz[dz['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów']>1000]
dz_large.describe()
# Out:
#        Nr OKW  Kod TERYT  Numer obwodu  \
# count    71.0       71.0     71.000000
# mean     21.0   149901.0     99.549296
# std       0.0        0.0     47.740007
# min      21.0   149901.0      9.000000
# 25%      21.0   149901.0     59.500000
# 50%      21.0   149901.0     99.000000
# 75%      21.0   149901.0    147.000000
# max      21.0   149901.0    168.000000
#
#        Komisje obwodowe otrzymały kart do głosowania  \
# count                                      71.000000
# mean                                      302.633803
# std                                       822.366624
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                      3514.000000
#
#        Liczba wyborców uprawnionych do głosowania  \
# count                                   71.000000
# ...

# %%
dd = dz_large.nlargest(5,'Andrzej Sebastian DUDA')
dd[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13967  Chicago II, Konsulat Generalny RP 1530 N Lake ...
# 13966  Chicago I, Konsulat Generalny RP 1530 N Lake S...
# 13968  Chicago III, Konsulat Generalny RP 1530 N Lake...
# 13906  Toronto, Konsulat Generalny RP 2603 Lake Shore...
# 13963  Nowy Jork III, Konsulat Generalny RP 233 Madis...
#
#        Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# 13967                                             3308.0
# 13966                                             3363.0
# 13968                                             3331.0
# 13906                                             3262.0
# 13963                                             3478.0
#
#        Robert BIEDROŃ  Krzysztof BOSAK  Andrzej Sebastian DUDA  \
# 13967        0.937122         4.836759               68.893591
# 13966        0.832590         4.936069               67.320844
# 13968        0.720504         5.884119               65.685980
# ...

# %%
dd = dz_large.nlargest(5,'Rafał Kazimierz TRZASKOWSKI')
dd[['Siedziba','Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                                 Siedziba  \
# 13920  Luksemburg, Ambasada RP 24, rue Guillaume Schn...
# 13891  Barcelona, Konsulat Generalny RP Avinguda Diag...
# 13931  Berlin III, Ambasada RP Lassenstraße 19 – 21 1...
# 13890  Madryt, Wydział Konsularny Ambasady RP c/ Goya...
# 13889  Madryt, Ambasada RP c/ Guisando, 23 bis (wejśc...
#
#        Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# 13920                                             1520.0
# 13891                                             1399.0
# 13931                                             2245.0
# 13890                                             1647.0
# 13889                                             1442.0
#
#        Robert BIEDROŃ  Krzysztof BOSAK  Andrzej Sebastian DUDA  \
# 13920        4.736842         2.697368               11.052632
# 13891       10.364546         2.287348                7.719800
# 13931        7.928731         4.231626               11.091314
# ...

# %%
df_dps = df[df['Typ obwodu'].str.startswith('dom pomocy')]
df_dps.shape
# Out:
# (646, 44)

# %%
df_dps[['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile].sum()
# Out:
# Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów    25830.0
# Robert BIEDROŃ                                                       894.0
# Krzysztof BOSAK                                                      389.0
# Andrzej Sebastian DUDA                                             19065.0
# Szymon Franciszek HOŁOWNIA                                          1019.0
# Marek JAKUBIAK                                                       275.0
# Władysław Marcin KOSINIAK-KAMYSZ                                     749.0
# Mirosław Mariusz PIOTROWSKI                                          235.0
# Paweł Jan TANAJNO                                                    122.0
# Rafał Kazimierz TRZASKOWSKI                                         2787.0
# Waldemar Włodzimierz WITKOWSKI                                       126.0
# Stanisław Józef ŻÓŁTEK                                               169.0
# dtype: float64

# %%
df_zk = df[df['Typ obwodu'].str.startswith('zakład kar')]
df_zk[['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile].sum()
# Out:
# Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów    27207
# Robert BIEDROŃ                                                       700
# Krzysztof BOSAK                                                      787
# Andrzej Sebastian DUDA                                              8314
# Szymon Franciszek HOŁOWNIA                                          3717
# Marek JAKUBIAK                                                        93
# Władysław Marcin KOSINIAK-KAMYSZ                                     502
# Mirosław Mariusz PIOTROWSKI                                           54
# Paweł Jan TANAJNO                                                     74
# Rafał Kazimierz TRZASKOWSKI                                        12806
# Waldemar Włodzimierz WITKOWSKI                                        58
# Stanisław Józef ŻÓŁTEK                                               102
# dtype: int64

# %%
df_typ = df.groupby('Typ obwodu').sum()
df_typ[['Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów'] + debile]
# Out:
#                                       Liczba głosów ważnych oddanych łącznie na wszystkich kandydatów  \
# Typ obwodu
# areszt śledczy                                                                    13714
# dom pomocy społecznej                                                             25830
# dom studencki                                                                       126
# oddział zewnętrzny aresztu śledczego                                               1523
# oddział zewnętrzny zakładu karnego                                                 1299
# statek                                                                              369
# stały                                                                          19004766
# zagranica                                                                        310699
# zakład karny                                                                      27207
# ...
